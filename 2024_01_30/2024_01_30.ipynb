# %% [markdown]
# # Series

# %%
import pandas as pd
import numpy as np

data = np.array(['g', 'e', 'e', 'k', 's'])

ser = pd.Series(data)
print(ser)
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %% [markdown]
# # Data Frames

# %%
import pandas as pd
data = {'name' : ['Tom', 'nick', 'krish', 'jack'], 
        'age' : [20, 21, 22, 23]}

df = pd.DataFrame(data)
print(df)
# Out:
#     name  age
# 0    Tom   20
# 1   nick   21
# 2  krish   22
# 3   jack   23

# %% [markdown]
# # Column Selection

# %%
import pandas as pd

data = {'name' : ['Tom', 'nick', 'krish', 'jack'],
        'age' : [20, 21, 22, 23],
        'address' : ['a', 'b', 'c', 'd']}

df = pd.DataFrame(data)

# selecting name, address columns
print(df[['name', 'address']])
# Out:
#     name address
# 0    Tom       a
# 1   nick       b
# 2  krish       c
# 3   jack       d

# %% [markdown]
# # Row Selection

# %% [markdown]
# ## loc method

# %%
import pandas as pd

data = pd.read_csv("nba.csv", index_col= "Name")

first = data.loc["Avery Bradley"]

second = data.loc["R.J. Hunter"]

print
print(first, "\n\n")
print(second)
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
#
#
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %% [markdown]
# ## iloc method

# %%
row2 = data.iloc[3]
print(row2)

display(data.iloc[[0,2, 4, 7]])

display(data.iloc[1: 5])

data.loc[((data.Number == 0, ['Team', 'College']))]
# Out:
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# Kelly Olynyk   Boston Celtics    41.0        C  25.0    7-0   238.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# John Holland   Boston University        NaN
# Jonas Jerebko                NaN  5000000.0
# Kelly Olynyk             Gonzaga  2165160.0
#                          Team  Number Position   Age Height  Weight  \
# Name
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0
#                                        Team           College
# Name
# Avery Bradley                Boston Celtics             Texas
# Shane Larkin                  Brooklyn Nets        Miami (FL)
# Isaiah Canaan            Philadelphia 76ers      Murray State
# Nick Young               Los Angeles Lakers               USC
# Willie Cauley-Stein        Sacramento Kings          Kentucky
# Aaron Brooks                  Chicago Bulls            Oregon
# Kevin Love              Cleveland Cavaliers              UCLA
# Andre Drummond              Detroit Pistons       Connecticut
# C.J. Miles                   Indiana Pacers               NaN
# Andrew Goudelock            Houston Rockets        Charleston
# JaMychal Green            Memphis Grizzlies           Alabama
# Orlando Johnson        New Orleans Pelicans  UC Santa Barbara
# Jeff Teague                   Atlanta Hawks       Wake Forest
# Spencer Hawes             Charlotte Hornets        Washington
# Josh Richardson                  Miami Heat         Tennessee
# Aaron Gordon                  Orlando Magic           Arizona
# Darrell Arthur               Denver Nuggets            Kansas
# Emmanuel Mudiay              Denver Nuggets               NaN
# Russell Westbrook     Oklahoma City Thunder              UCLA
# Damian Lillard       Portland Trail Blazers       Weber State

# %% [markdown]
# # Matplotlib Pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np 

xpoints = np.array([0, 5])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)

plt.show()
