# %%
# Matrix Addition

m = int(input())
n = int(input())

a = []

# input matrix a
for i in range(m) :
    row = []
    for j in range(n) :
        row.append(int(input()))
    a.append(row)

b = []

# input matrix b
for i in range(m) :
    row = []
    for j in range(n) :
        row.append(int(input()) + a[i][j])
    b.append(row)

print(b)
# Out:
# 2
# 2
# 3
# 1
# 2
# 4
# 5
# 9
# 6
# 1
# [[-2, -8], [-4, 3]]

# %%
# Matrix Subtraction

m = int(input("No. of Rows : "))
n = int(input("No. of Cols : "))

a = []

# input matrix a
print("# Enter Elements of A: ")
for i in range(m) :
    row = []
    for j in range(n) :
        row.append(int(input()))
    a.append(row)

b = []
print("# Enter Elements of B: ")
# input matrix b
for i in range(m) :
    row = []
    for j in range(n) :
        row.append(a[i][j] - int(input()))
    b.append(row)

print(b)
# Out:
# No. of Rows : 2
# No. of Cols : 1
# # Enter Elements of A:
# 1
# 2
# # Enter Elements of B:
# 3
# 4
# [[-2], [-2]]

# %%
# Matrix Multiplication

m1 = int(input("No. of Rows A: "))
n1 = int(input("No. of Cols A: "))

m2 = int(input("No. of Rows B: "))
n2 = int(input("No. of Cols B: "))

if m2 != n1 :
    printf("Multiplication Not Possible")
    
else :
    a = []

    # input matrix a
    print("# Enter Elements of A: ")
    for i in range(m1) :
        row = []
        for j in range(n1) :
            row.append(int(input()))
        a.append(row)


    b = []
    print("# Enter Elements of B: ")
    # input matrix b
    for i in range(m2) :
        row = []
        for j in range(n2) :
            row.append(int(input()))
        b.append(row)
    
    # Multiplication
    c = []
    
    # row in a
    for i in range(m1) :
        # col in b
        row = []
        for j in range(n2) :
            # sum of products or row and column
            tot = 0
            for k in range(n1) :
                tot += (a[i][k] * b[k][j])
            row.append(tot)
        c.append(row)

    print(c)
# Out:
# No. of Rows A: 2
# No. of Cols A: 2
# No. of Rows B: 2
# No. of Cols B: 2
# # Enter Elements of A:
# 2
# 2
# 2
# 2
# # Enter Elements of B:
# 2
# 2
# 2
# 2
# [[8, 8], [8, 8]]

# %%
# Matrix Transpose

m = int(input())
n = int(input())

a = []

# input matrix a
for i in range(m) :
    row = []
    for j in range(n) :
        row.append(int(input()))
    a.append(row)

print("A : ", a)

b = []
# Transpose matrix    
for i in range(n) :
    row = []
    for j in range(m) :
        row.append(a[j][i])
    b.append(row)

print("B : ", b)
# Out:
# 2
# 3
# 4
# 5
# 9
# 6
# 2
# 1
# A :  [[4, 5, 9], [6, 2, 1]]
# B :  [[4, 6], [5, 2], [9, 1]]

# %%
# Matrix Min, Max

m = int(input())
n = int(input())

a = []

"""
m1 - min
m2 - max
"""
m1 = float('inf')
m2 = 0
# input matrix a
for i in range(m) :
    row = []
    for j in range(n) :
        row.append(int(input()))
        m1 = min(row[j], m1)
        m2 = max(row[j], m2)
    a.append(row)

print("min : ", m1)
print("max : ", m2)

# %%
# Matrix Min, Max of col

m = int(input())
n = int(input())

a = []

"""
m1 - min
m2 - max
"""
# input matrix a
for i in range(m) :
    row = []
    for j in range(n) :
        row.append(int(input()))
    a.append(row)

print("A :", a)
# finding min max
col = 0;
for i in range(n) :
    m1 = float('inf')
    m2 = 0
    col += 1
    for j in range(m) :
        m1 = min(row[j], m1)
        m2 = max(row[j], m2)
    print("Col : ", col)
    print("  min : ", m1)
    print("  max : ", m2)

# %%
### Trace of matrix

n = int(input("Dimension n in `n x n` : "))

s = 0
for i in range(n) :
    for j in range(n) :
        k = int(input())
        if i == j :
            s += k
print("Trace : ", s)
# Out:
# Dimension n in `n x n` : 3
# 1
# 3
# 4
# 5
# 2
# 1
# 6
# 0
# 9
# Trace :  12

# %%
# mean of n elements
import math

n = int(input())

a = []
s = 0
for i in range(n) :
    a.append(int(input()))
    s += a[i]

s = s / n
print("Mean is : ", s)

# standard Deviation

sqr_s = 0
for i in range(n) :
    sqr_s += (a[i] - s) ** 2
sqr_s /= n
sqr_s = math.sqrt(sqr_s)

print("Standard Deviation is : ", sqr_s)

# median of n elements

a.sort()

if n % 2 :
    print("Median is ", a[n//2])
else :
    print("Median is ", (a[n//2] + a[n//2 - 1]) / 2)
# Out:
# 5
# 1
# 2
# 3
# 4
# 5
# Mean is :  3.0
# Standard Deviation is :  1.4142135623730951
# Median is  3

# %%
# mode of array

n = int(input())

a = {}
for i in range(n) :
    b = int(input())
    
    if b not in a :
        a[b] = 1
    else :
        a[b] += 1
ans = -1
maxi = 0
for i in a :
    if a[i] > maxi :
        maxi = a[i]
        ans = i

print(ans)
# Out:
# 5
# 1
# 1
# 2
# 2
# 2
# 2

# %%
# inverse of a matrix
N = 4

# Function to get cofactor of A[p][q]
# dimension of A[][]
def getCofactor(A, temp, p, q, n):

    i = 0
    j = 0

    # Looping for each element of the matrix
    for row in range(n):

        for col in range(n):

            # Copying into temporary matrix only those element
            # which are not in given row and column
            if (row != p and col != q):

                temp[i][j] = A[row][col]
                j += 1

                # Row is filled, so increase row index and
                # reset col index
                if (j == n - 1):
                    j = 0
                    i += 1


# Recursive function for finding determinant of matrix.
# n is current dimension of A[][].
def determinant(A, n):

    D = 0 # Initialize result

    # Base case : if matrix contains single element
    if (n == 1):
        return A[0][0]

    temp = [] # To store cofactors
    for i in range(N):
        temp.append([None for _ in range(N)])

    sign = 1 # To store sign multiplier

    # Iterate for each element of first row
    for f in range(n):

        # Getting Cofactor of A[0][f]
        getCofactor(A, temp, 0, f, n)
        D += sign * A[0][f] * determinant(temp, n - 1)

        # terms are to be added with alternate sign
        sign = -sign

    return D


# Function to get adjoint of A[N][N] in adj[N][N].
def adjoint(A, adj):

    if (N == 1):
        adj[0][0] = 1
        return

    # temp is used to store cofactors of A[][]
    sign = 1
    temp = [] # To store cofactors
    for i in range(N):
        temp.append([None for _ in range(N)])

    for i in range(N):
        for j in range(N):
            # Get cofactor of A[i][j]
            getCofactor(A, temp, i, j, N)

            # sign of adj[j][i] positive if sum of row
            # and column indexes is even.
            sign = [1, -1][(i + j) % 2]

            # Interchanging rows and columns to get the
            # transpose of the cofactor matrix
            adj[j][i] = (sign)*(determinant(temp, N-1))


# Function to calculate and store inverse, returns false if
# matrix is singular
def inverse(A, inverse):

    # Find determinant of A[][]
    det = determinant(A, N)
    if (det == 0):
        print("Singular matrix, can't find its inverse")
        return False

    # Find adjoint
    adj = []
    for i in range(N):
        adj.append([None for _ in range(N)])
    adjoint(A, adj)

    # Find Inverse using formula "inverse(A) = adj(A)/det(A)"
    for i in range(N):
        for j in range(N):
            inverse[i][j] = adj[i][j] / det

    return True


# Generic function to display the
# matrix. We use it to display
# both adjoin and inverse. adjoin
# is integer matrix and inverse
# is a float.
def display(A):
    for i in range(N):
        for j in range(N):
            print(A[i][j], end=" ")
        print()


def displays(A):
    for i in range(N):
        for j in range(N):
            print(round(A[i][j], 6), end=" ")
        print()


# Driver program

A = [[5, -2, 2, 7], [1, 0, 0, 3], [-3, 1, 5, 0], [3, -1, -9, 4]]
adj = [None for _ in range(N)]
inv = [None for _ in range(N)]

for i in range(N):
    adj[i] = [None for _ in range(N)]
    inv[i] = [None for _ in range(N)]

print("Input matrix is :")
display(A)

print("\nThe Adjoint is :")
adjoint(A, adj)
display(adj)

print("\nThe Inverse is :")
if (inverse(A, inv)):
    displays(inv)
# Out:
# [[None, None, None, None], [None, None, None, None], [None, None, None, None], [None, None, None, None]]  [[None, None, None, None], [None, None, None, None], [None, None, None, None], [None, None, None, None]]
# Input matrix is :
# 5 -2 2 7
# 1 0 0 3
# -3 1 5 0
# 3 -1 -9 4
#
# The Adjoint is :
# -12 76 -60 -36
# -56 208 -82 -58
# 4 4 -2 -10
# 4 4 20 12
#
# The Inverse is :
# -0.136364 0.863636 -0.681818 -0.409091
# -0.636364 2.363636 -0.931818 -0.659091
# 0.045455 0.045455 -0.022727 -0.113636
# 0.045455 0.045455 0.227273 0.136364
